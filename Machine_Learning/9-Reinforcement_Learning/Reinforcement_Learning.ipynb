# %% [markdown]
# ## ¿Qué es el Aprendizaje por Refuerzo?
#
#
# Seguramente ya conocerás las 2 grandes áreas de aprendizaje tradicional del Machine Learning, el aprendizaje supervisado y el aprendizaje no supervisado. Parece difícil que aquí hubiera espacio para otras opciones; sin embargo sí la hay y es el Aprendizaje por refuerzo. En aprendizaje por refuerzo (ó Reinforcement Learning en inglés) no tenemos una “etiqueta de salida”, por lo que no es de tipo supervisado y si bien estos algoritmos aprenden por sí mismos, tampoco son de tipo no supervisado, en donde se intenta clasificar grupos teniendo en cuenta alguna distancia entre muestras.
#
# ![foto1](img/areas-ml.png)
#
# ![foto4](img/1_YIETknPBlQQBF40DJxL8QA.png)
#
# Si nos ponemos a pensar, los problemas de ML supervisados y no supervisados son específicos de un caso de negocio en particular, sea de clasificación ó predicción, están muy delimitados, por ejemplo, clasificar “perros ó gatos“, ó agrupar “k=5” clusters. En contraste, en el mundo real contamos con múltiples variables que por lo general se interrelacionan y que dependen de otros casos de negocio y dan lugar a escenarios más grandes en donde tomar decisiones. Para conducir un coche no basta una inteligencia que pueda detectar un semáforo en rojo, verde ó amarillo; tendremos muchísimos factores -todos a la vez- a los que prestar atención: a qué velocidad vamos, estamos ante una curva?, hay peatones?, es de noche y debemos encender las luces?.
#
# Una solución sería tener múltiples máquinas de ML supervisadas y que interactúan entre si -y esto no estaría mal- ó podemos cambiar el enfoque… Y ahí aparece el Reinforcement Learning (RL) como una alternativa, tal vez de las más ambiciosas en las que se intenta integrar el Machine Learning en el mundo real, sobre todo aplicado a robots y maquinaria industrial.
#
# El Reinforcement Learning entonces, intentará hacer aprender a la máquina basándose en un esquema de “premios y castigos” -cómo con el perro de Pablov- en un entorno en donde hay que tomar acciones y que está afectado por múltiples variables que cambian con el tiempo.
#
# ![foto2](img/496302-1548589.jpg)
#
#
# ## Diferencias con “los clásicos”
#
# En los modelos de Aprendizaje Supervisado (o no supervisado) como redes neuronales, árboles, knn, etc, se intenta “minimizar la función coste”, reducir el error.
#
# En cambio en el RL se intenta “maximizar la recompensa“. Y esto puede ser, a pesar de a veces cometer errores ó de no ser óptimos.
#
# Componentes del RL
# El Reinforcement Learning propone un nuevo enfoque para hacer que nuestra máquina aprenda, para ello, postula los siguientes 2 componentes:
#
# el Agente: será nuestro modelo que queremos entrenar y que aprenda a tomar decisiones.
#
# Ambiente: será el entorno en donde interactúa y “se mueve” el agente. El ambiente contiene las limitaciones y reglas posibles a cada momento.
# Entre ellos hay una relación que se retroalimenta y cuenta con los siguientes nexos:
#
# Acción: las posibles acciones que puede tomar en un momento determinado el Agente.
#
# Estado (del ambiente): son los indicadores del ambiente de cómo están los diversos elementos que lo componen en ese momento.
#
# Recompensas (ó castigos!): a raíz de cada acción tomada por el Agente, podremos obtener un premio ó una penalización que orientarán al Agente en si lo está haciendo bien ó mal.
#
# ![foto3](img/premio-castigo.png)

# %% [markdown]
# ## Empecemos a trabajar Obreros..

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 3.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from gym) (3.0.0)
# Collecting gym-notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827615 sha256=4ae595de3db182a7d078dcff7619df6d1cfe59b792996f21c4159f1fce237b66
#   Stored in directory: /Users/hectormoya/Library/Caches/pip/wheels/1c/77/9e/9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built gym
# Installing collected packages: gym-notices, gym
# Successfully installed gym-0.26.2 gym-notices-0.0.8

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import random
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Cart Pole.
#
# ![foto5](img/0-923627-95182.gif)
#
# Se trata de un péndulo que está en posición vertical y debemos mover el carro de abajo para que no caiga a ninguno de los lados.
#
# Este entorno es un problema clásico y como tal, ya está diseñado por nosotros en diferentes librerías. Nosotros usaremos OpenAI Gym. Se trata de una librería que provee de varios entornos interesantes para poner a prueba nuestros algoritmos, con representación gráfica de los mismos.
#
# Este entorno se caracteriza por tener cuatro entradas: posición del carro, velocidad del carro, ángulo del péndulo y velocidad angular del péndulo. Y dos acciones: acelerar a la izquierda y acelerar a la derecha. Las recompensas son 1 por cada acción tomada. El episodio finaliza cuando el ángulo del péndulo supera los 12 grados, el carro se aleja demasiado del centro y cuando el episodio alcanza los 200 pasos.
#
# Vamos a ver como funciona la interfaz Gym para que luego seamos capaces de crear nuestros propios entornos. Esta se compone de:
#
# Una clase que hereda de **gym.Env**
#
# Un constructor donde inicializamos, como mínimo, self.action_space, self.observation_space y opcionalmente self.reward_range y parámetros internos del entorno nuestro. Estas dos primeras deben ser de algún subtipo **gym.spaces**. Los más normales son **Discrete**, que es básicamente un valor activado sobre N posibles y Box, que es una matriz de características (podemos especificar la forma para que sea unidimensional, o que tenga más dimensiones), que contiene números.
# Es muy habitual que las observaciones sean de tipo Box, ya que se miden varias características a la vez, con números decimales y **Discrete** sea para las acciones ya que tomamos una acción de N posibles. Pero otras combinaciones son posibles y existen más tipos de **gym.spaces**. Si vamos a introducir características diferentes dentro del mismo Box es muy conveniente normalizar los datos entre -1 y 1. self.reward_range, al contrario, es una tupla en la que se especifica el valor máximo y el mínimo que pueden alcanzar las recompensas.
#
# Un método **reset**, que reinicia el entorno y devuelve una observación inicial. Estas observaciones, deberán devolverse con NumPy si son de tipo Box y coincidir con lo declarado en el constructor en cuanto a forma y tipos.
#
# Un método **step** que toma una acción y devuelve una tupla con cuatro valores: nueva observación, recompensa, un boolean de si el episodio ha acabado ya o no y un diccionario de información extra (no usado por los algoritmos).
#
# Opcionalmente pueden llevar instrucciones sobre como renderizar el entorno y así ver en vivo o en vídeo el funcionamiento de los algoritmos. Principalmente se controla a través del método **render**.

# %% [markdown]
# [cartpole](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)

# %%
env=gym.make('CartPole-v0') # Crea el entorno de juego correspondiente



env=env.unwrapped #Opcional, agregue restricciones al medio ambiente, beneficioso para la capacitación

# ---------------------- Espacio de acción y espacio de estado --------------------- #

print("Action Space {}".format(env.action_space)) # Posibles Movimientos

print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(2)
# State Space Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env = gym.make('CartPole-v0')

# %%
env.reset()
for _ in range(100):
    env.render()
    env.step(env.action_space.sample())

# %%
env.close()

# %% [markdown]
# Bien ahora tenemos un carrito idiota que no hace nada solo moverse...

# %% [markdown]
# Si queremos tomar acciones que son mejores que las aleatorias en cada paso, entonces sería bueno comprender realmente cómo nuestras acciones afectan el medio ambiente. A
# La función de paso del entorno devolverá la información que necesitamos. La función paso devuelve cuatro valores, la siguiente es la información específica:
#
# Observación (objet): un objeto relacionado con el entorno describe el entorno que observa, como la información de píxeles de la cámara, el ángulo y la velocidad angular del robot y el estado del tablero en un juego de mesa.
#
# recompensa (float): La suma de todas las recompensas obtenidas de acciones anteriores. Los diferentes entornos tienen diferentes métodos de cálculo, pero el objetivo siempre ha sido aumentar tus recompensas totales.
#
# done (booleano): para determinar si es el momento de restablecer el entorno, la mayoría de las tareas se dividen en episodios claramente definidos, y done es True para indicar que el episodio ha terminado.
#
# info (dict): información de diagnóstico para depuración. A veces también es útil para aprender (por ejemplo, puede contener la probabilidad original después del último cambio de estado del entorno). Pero la evaluación formal del agente no permite el uso de esta información para el aprendizaje

# %% [markdown]
# [cartpole.py](./cartpole.py)

# %%
for i_episode in range(20):
    observation = env.reset()

    
    for t in range(100):
        env.render()
        print(observation[0])
        
        observation, reward, done, _, info = env.step(action)

        action = int(observation[2]> 0.0 and observation[3] > 0.0)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# [ 0.04599547 -0.03274192 -0.02807112  0.01664602]
# 0.04534063
# 0.040791627
# 0.0323483
# 0.020008763
# 0.0037695458
# -0.008569163
# -0.017014002
# -0.021570457
# -0.022242438
# -0.019032033
# -0.019741753
# -0.016567798
# -0.017313212
# -0.014174189
# -0.014954163
# -0.011849434
# -0.012663705
# -0.00959349
# -0.010442651
# -0.0074080196
# -0.008293518
# -0.005296412
# 0.0015814505
# 0.0045381533
# 0.011377351
# 0.014296455
# 0.021099225
# 0.023982568
# 0.03075022
# 0.033598732
# 0.040331703
# 0.043145433
# 0.049843285
# 0.052621424
# 0.059282865
# 0.062023737
# 0.06864657
# 0.07914945
# 0.08573054
# 0.09619325
# 0.1027351
# 0.11315956
# 0.11966368
# 0.13005084
# 0.13651778
# 0.14686766
# 0.15329704
# 0.16360874
# 0.16999926
# 0.18027097
# 0.18662037
# 0.19684927
# 0.21095549
# 0.22113773
# 0.23519842
# 0.24533568
# 0.25935188
# 0.2694447
# 0.28341627
# 0.29346412
# 0.30738991
# 0.31739113
# 0.33126885
# 0.3490209
# 0.36284703
# 0.38054883
# 0.39432526
# 0.41197795
# 0.42570537
# 0.4433089
# 0.45698673
# 0.47453982
# 0.48816636
# 0.50566655
# 0.5270381
# 0.5444816
# 0.56579757
# 0.58318585
# 0.6044469
# 0.6217801
# 0.6429855
# 0.6602624
# 0.6814102
# 0.70642656
# 0.7275132
# 0.7524698
# 0.773497
# 0.7983944
# 0.8193624
# 0.8442001
# 0.86510766
# 0.8898836
# 0.91852546
# 0.9432359
# 0.97181344
# 0.99645984
# 1.0249735
# 1.0495557
# 1.0780044
# [0.02382268 0.02653806 0.02645162 0.02582037]
# 0.024353439
# 0.028778857
# 0.029294347
# 0.03370589
# 0.034208674
# 0.038608704
# 0.03910099
# 0.04349155
# 0.04397526
# 0.048358135
# 0.048834946
# 0.053211708
# 0.05368311
# 0.058055155
# 0.058522474
# 0.062891066
# 0.06335551
# 0.067721814
# 0.06818452
# 0.072549604
# 0.07301163
# 0.06957168
# 0.07003406
# 0.07439648
))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(max(maximo))
#
# NameError: name 'maximo' is not defined

# %% [markdown]
# ## Stable Baselines
#
# Este algoritmo, DQN, es muy popular, y se encuentra implementado en diferentes librerías. Una de las más interesantes es Stable Baselines 3, que intenta ser el sklearn del aprendizaje por refuerzo. Usa PyTorch internamente. Con Stable Baselines 3, debemos proporcionar un entorno que siga la interfaz Gym y ajustar los hiperparámetros. En el caso de DQN los hiperparámetros más importantes son:
#
# - **policy** - La política a usar del modelo. Casi siempre MlpPolicy. Si la entrada son imágenes, CnnPolicy.
# - **env** - El entorno sobre el que vamos a aprender. Debe implementar la interfaz OpenAI Gym
# - **learning_rate** - Ratio de aprendizaje de la red neuronal
# - **buffer_size** - El tamaño del buffer que almacenará las transiciones del "experience replay".
# - **batch_size** - Tamaño del batch que se usa para reentrenar.
# - **learning_starts** - Cuantos steps debe dar el modelo antes de empezar a aprender la red neuronal.
# - **gamma** - el factor de descuento. En posts anteriores hemos hablado de él.
# - **train_freq** - Cada cuantos steps se reentrena el modelo.
# - **gradient_steps** - Cuantos pasos de gradiente se dan al entrenar. Por defecto, 1.
# - **target_update_interval** - Cada cuantos steps se actualiza el "fixed Q-target".
# - **policy_kwargs** - Ajustes de la política. En el caso de MlpPolicy podremos ajustar la forma de la red,
#                     así como las funciones de activación   y más detalles.

# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (1.26.4)
# Collecting torch>=1.13 (from stable-baselines3[extra])
#   Downloading torch-2.2.1-cp311-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: cloudpickle in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: matplotlib in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: opencv-python in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (4.9.0.80)
# Collecting pygame (from stable-baselines3[extra])
#   Downloading pygame-2.5.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (2.15.2)
# Requirement already satisfied: psutil in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (5.9.7)
# Requirement already satisfied: tqdm in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (4.66.2)
# Requirement already satisfied: rich in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (13.7.0)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from stable-baselines3[extra]) (10.2.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 5.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp311-cp311-macosx_10_15_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.62.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Requirement already satisfied: six>1.9 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.1)
# Collecting filelock (from torch>=1.13->stable-baselines3[extra])
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch>=1.13->stable-baselines3[extra])
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.3)
# Collecting fsspec (from torch>=1.13->stable-baselines3[extra])
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from pandas->stable-baselines3[extra]) (2023.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Using cached importlib_resources-6.1.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->stable-baselines3[extra])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading torch-2.2.1-cp311-none-macosx_10_9_x86_64.whl (150.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading pygame-2.5.2-cp311-cp311-macosx_10_9_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 4.6 MB/s eta 0:00:00
# Downloading ale_py-0.8.1-cp311-cp311-macosx_10_15_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.7 MB/s eta 0:00:0000:01
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 4.1 MB/s eta 0:00:00ta 0:00:01
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 17.6 MB/s eta 0:00:0000:0100:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 12.1 MB/s eta 0:00:0000:01
# Downloading importlib_resources-6.1.2-py3-none-any.whl (34 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=858f94c8dd20502f7176c73e5247d143737c7ea28948f80400c2e7a60e6f870e
#   Stored in directory: /Users/hectormoya/Library/Caches/pip/wheels/bc/fc/c6/8aa657c0d2089982f2dabd110efc68c61eb49831fdb7397351
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: mpmath, sympy, pygame, importlib-resources, fsspec, filelock, torch, shimmy, AutoROM.accept-rom-license, autorom, ale-py, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 filelock-3.13.1 fsspec-2024.2.0 importlib-resources-6.1.2 mpmath-1.3.0 pygame-2.5.2 shimmy-1.3.0 stable-baselines3-2.2.1 sympy-1.12 torch-2.2.1

# %%
from stable_baselines3 import DQN
# Out:
# 2024-03-04 20:00:24.065106: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
env = gym.make("CartPole-v1")
env.reset()
for _ in range(100):
    env.render()
    env.step(env.action_space.sample())

# %%
env.close()

# %%
model = DQN(
    "MlpPolicy",
    env,
    learning_rate=1e-3,
    buffer_size=50000,
    learning_starts=10000,
    batch_size=64,
    gamma=0.999,
    gradient_steps=1,
    train_freq=20,
    target_update_interval=2000,
    verbose=1
    )
model.learn(total_timesteps=500_000)
model.save("dqn_cartpole")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5598     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6862     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7357     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7277     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 310      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7410     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7763     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7588     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 563      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7723     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7703     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 830      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7770     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 907      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8199     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8233     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8179     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8172     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8224     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8254     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8261     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8306     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8396     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8394     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6493     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6066     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6124     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6165     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2183     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6203     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6234     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 6324     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6316     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6347     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6371     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 6465     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6497     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6647     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6682     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 6698     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6806     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6836     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 6846     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 6814     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 6890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 6933     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 6958     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 6984     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7135     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7140     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7160     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7148     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4501     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7165     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7172     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7207     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7253     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 7341     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 7384     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 7423     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 7441     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 7456     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 7452     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 7488     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 7513     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 7504     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 7514     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 7519     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 7493     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 7467     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 7430     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 7429     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6333     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 7441     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 7446     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 7464     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 7469     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 7501     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6781     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 7516     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 7540     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 7511     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 7493     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 7494     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 7514     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 7526     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 7552     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 7578     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 7584     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7617     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 7588     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 7574     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 7552     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 7540     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 7518     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 7286     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 7200     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 7149     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 6949     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 6866     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 6789     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8501     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 6776     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 6742     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 6717     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 6704     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 6712     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 6708     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 6693     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 6665     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 6664     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 6664     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 6660     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 6699     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 6689     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 6705     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 6720     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 6713     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5958     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10079    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.481    |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5904     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10154    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.421    |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5828     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10276    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.324    |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5774     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10380    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.236    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5710     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10507    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.121    |
# |    n_updates        | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5680     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10594    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0761   |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5605     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10739    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0226   |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5542     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10809    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0197   |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5486     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10939    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0283   |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# ...
# |    time_elapsed     | 201      |
# |    total_timesteps  | 439731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.111    |
# |    n_updates        | 21486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5548     |
# |    fps              | 2187     |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 441731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.61     |
# |    n_updates        | 21586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5552     |
# |    fps              | 2186     |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 443731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.67     |
# |    n_updates        | 21686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5556     |
# |    fps              | 2186     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 445731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.65     |
# |    n_updates        | 21786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5560     |
# |    fps              | 2186     |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 447731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0349   |
# |    n_updates        | 21886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5564     |
# |    fps              | 2184     |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 449731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0594   |
# |    n_updates        | 21986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 247      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5568     |
# |    fps              | 2182     |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 451731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.043    |
# |    n_updates        | 22086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | 267      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5572     |
# |    fps              | 2182     |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 453731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.68     |
# |    n_updates        | 22186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 286      |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5576     |
# |    fps              | 2182     |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 455731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0292   |
# |    n_updates        | 22286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 306      |
# |    ep_rew_mean      | 306      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5580     |
# |    fps              | 2183     |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 457731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.73     |
# |    n_updates        | 22386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | 325      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5584     |
# |    fps              | 2183     |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 459731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.59     |
# |    n_updates        | 22486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 345      |
# |    ep_rew_mean      | 345      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5588     |
# |    fps              | 2185     |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 461731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.72     |
# |    n_updates        | 22586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 364      |
# |    ep_rew_mean      | 364      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5592     |
# |    fps              | 2185     |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 463731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0345   |
# |    n_updates        | 22686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 384      |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5596     |
# |    fps              | 2185     |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 465731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0607   |
# |    n_updates        | 22786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 398      |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5600     |
# |    fps              | 2184     |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 467731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0418   |
# |    n_updates        | 22886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5604     |
# |    fps              | 2183     |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 469731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0225   |
# |    n_updates        | 22986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5608     |
# |    fps              | 2182     |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 471731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0166   |
# |    n_updates        | 23086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5612     |
# |    fps              | 2181     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 473731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0189   |
# |    n_updates        | 23186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5616     |
# |    fps              | 2179     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 475731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0238   |
# |    n_updates        | 23286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 485      |
# |    ep_rew_mean      | 485      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5620     |
# |    fps              | 2179     |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 477731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0144   |
# |    n_updates        | 23386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 495      |
# |    ep_rew_mean      | 495      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5624     |
# |    fps              | 2180     |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 479731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0175   |
# |    n_updates        | 23486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5628     |
# |    fps              | 2180     |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 481731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0315   |
# |    n_updates        | 23586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5632     |
# |    fps              | 2181     |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 483731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0189   |
# |    n_updates        | 23686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5636     |
# |    fps              | 2182     |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 485731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0124   |
# |    n_updates        | 23786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5640     |
# |    fps              | 2183     |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 487731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0151   |
# |    n_updates        | 23886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5644     |
# |    fps              | 2183     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 489731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0166   |
# |    n_updates        | 23986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5648     |
# |    fps              | 2183     |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 491731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0148   |
# |    n_updates        | 24086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5652     |
# |    fps              | 2182     |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 493731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0205   |
# |    n_updates        | 24186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5656     |
# |    fps              | 2182     |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 495731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0504   |
# |    n_updates        | 24286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5660     |
# |    fps              | 2182     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 497731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0151   |
# |    n_updates        | 24386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5664     |
# |    fps              | 2175     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 499731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.02     |
# |    n_updates        | 24486    |
# ----------------------------------

# %%
model = DQN.load("dqn_cartpole")

obs = env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 5
#       3 obs = env.reset()
#       4 for i in range(1000):
# ----> 5     action, _state = model.predict(obs, deterministic=True)
#       6     obs, reward, done, info = env.step(action)
#       7     env.render()
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:255, in DQN.predict(self, observation, state, episode_start, deterministic)
#     253         action = np.array(self.action_space.sample())
#     254 else:
# --> 255     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     256 return action, state
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/stable_baselines3/common/policies.py:355, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     352 # Check for common mistake that the user does not mix Gym/VecEnv API
#     353 # Tuple obs are not supported by SB3, so we can safely do that check
#     354 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
# --> 355     raise ValueError(
#     356         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     357         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#     358         "vs `obs = vec_env.reset()` (SB3 VecEnv). "
#     359         "See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 "
#     360         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     361     )
#     363 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     365 with th.no_grad():
#
# ValueError: You have passed a tuple to the predict() function instead of a Numpy array or a Dict. You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) vs `obs = vec_env.reset()` (SB3 VecEnv). See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api

# %%
env.close()

# %% [markdown]
# Ahora vamos con otro ejemplo..

# %% [markdown]
# ## MountainCar
#
# ![foto7](img/MountainCar.gif)

# %%
env = gym.make('MountainCar-v0')

# %%
env.reset()
for i in range(300):
    env.render()
    env.step(env.action_space.sample()) # accion random

# %%
env.close()

# %%
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break

# %% [markdown]
# [mountaincar.py](./mountaincar.py)

# %% [markdown]
# Otro ejemplo..

# %% [markdown]
# ## Taxi
#
# ![foto8](img/ezgif.com-video-to-gif1.gif)

# %%
# !pip install pygame --upgrade
# Out:
# Requirement already satisfied: pygame in /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages (2.5.2)

# %%
print(env.render(mode="ansi"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(env.render(mode="ansi"))
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/wrappers/order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/wrappers/env_checker.py:55, in PassiveEnvChecker.render(self, *args, **kwargs)
#      53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
# ---> 55     return self.env.render(*args, **kwargs)
#
# TypeError: TaxiEnv.render() got an unexpected keyword argument 'mode'
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
import gym

# Crear el entorno
env = gym.make("Taxi-v3").env

# Resetear el entorno para obtener el estado inicial
initial_state = env.reset()

# Ahora puedes renderizar el entorno sin problemas
env.render()
# Out:
# /Users/hectormoya/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/envs/toy_text/taxi.py:282: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("Taxi-v3", render_mode="rgb_array")
#   logger.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 10
#       7 initial_state = env.reset()
#       9 # Ahora puedes renderizar el entorno sin problemas
# ---> 10 env.render()
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/wrappers/order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/wrappers/env_checker.py:53, in PassiveEnvChecker.render(self, *args, **kwargs)
#      51 if self.checked_render is False:
#      52     self.checked_render = True
# ---> 53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
#      55     return self.env.render(*args, **kwargs)
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:316, in env_render_passive_checker(env, *args, **kwargs)
#     310     else:
#     311         assert env.render_mode is None or env.render_mode in render_modes, (
#     312             "The environment was initialized successfully however with an unsupported render mode. "
#     313             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     314         )
# --> 316 result = env.render(*args, **kwargs)
#     318 # TODO: Check that the result is correct
#     320 return result
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/envs/toy_text/taxi.py:290, in TaxiEnv.render(self)
#     288     return self._render_text()
#     289 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 290     return self._render_gui(self.render_mode)
#
# File ~/Documents/GitHub/DS_PT_09_2023/.venv/lib/python3.11/site-packages/gym/envs/toy_text/taxi.py:309, in TaxiEnv._render_gui(self, mode)
#     305     elif mode == "rgb_array":
#     306         self.window = pygame.Surface(WINDOW_SIZE)
#     308 assert (
# --> 309     self.window is not None
#     310 ), "Something went wrong with pygame. This should never happen."
#     311 if self.clock is None:
#     312     self.clock = pygame.time.Clock()
#
# AssertionError: Something went wrong with pygame. This should never happen.

# %% [markdown]
# Hay 4 ubicaciones (etiquetadas con letras diferentes), y nuestro trabajo es recoger al pasajero en una ubicación y dejarlo en otra. Recibimos +20 puntos por una entrega exitosa y perdemos 1 punto por cada paso de tiempo que toma. También hay una penalización de 10 puntos por acciones ilegales de recogida y entrega.

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))

# %%
print(env.s)

# %% [markdown]
# Como se verifica en las impresiones, tenemos un espacio de acción de tamaño 6 y un espacio de estado de tamaño 500. Como verá, nuestro algoritmo RL no necesitará más información que estas dos cosas. Todo lo que necesitamos es una forma de identificar un estado de manera única asignando un número único a cada estado posible, y RL aprende a elegir un número de acción del 0 al 5 donde:
#
# - 0 = sur
# - 1 = norte
# - 2 = este
# - 3 = oeste
# - 4 = recoger
# - 5 = dejar

# %%
state = env.encode(3, 1, 2, 0) # (taxi row, taxi column, passenger index, destination index)
print("State:", state)

env.s = state
env.render()

# %%
env.s = 328  # set environment to illustration's state

epochs = 0
penalties, reward = 0, 0

frames = [] # for animation

done = False

while not done:
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    # Añade +1 a la variable penaltie cuando el reward sea -10
    if reward == -10:
        penalties = penalties + 1
    # Put each rendered frame into dict for animation
    frames.append({
        'frame': env.render(mode='ansi'),
        'state': state,
        'action': action,
        'reward': reward
        }
    )

    epochs += 1

print("Timesteps taken: {}".format(epochs))
print("Penalties incurred: {}".format(penalties))

# %%
from IPython.display import clear_output
from time import sleep

def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'])
        print(f"Timestep: {i + 1}")
        print(f"State: {frame['state']}")
        print(f"Action: {frame['action']}")
        print(f"Reward: {frame['reward']}")
        sleep(.1)
        
print_frames(frames)

# %%
# Crea un array2d de ceros del tamaño de los diferentes estados y las diferentes posibles acciones
q_table = np.zeros([env.observation_space.n, env.action_space.n])
q_table

# %%
random.uniform(0, 1)

# %%
# %%time
"""Training the agent"""

import random
from IPython.display import clear_output
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1

# For plotting metrics
all_epochs = []
all_penalties = []

for i in range(1, 100001):
    state = env.reset()

    epochs, penalties, reward, = 0, 0, 0
    done = False
    
    while not done:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample() # Explore action space
        else:
            action = np.argmax(q_table[state]) # Exploit learned values

        next_state, reward, done, info = env.step(action) 
        
        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value

        if reward == -10:
            penalties += 1

        state = next_state
        epochs += 1
        
    if i % 100 == 0:
        clear_output(wait=True)
        print(f"Episode: {i}")

print("Training finished.\n")

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    env.reset()
    # Crea el estado inicial
    state = env.encode(3, 1, 2, 0)
    env.s = state
    # Inicializa las epochs, penalties y rewards
    epochs, penalties, reward = 0, 0, 0

    done = False
    actions = []
    while not done:
        # Elige la accion que te indique el maximo valor de la q_table
        action = np.argmax(q_table[state])
        actions.append(action)
        # Ejecuta la accion
        state, reward, done, info = env.step(action)

        # Actualiza el valor de penalties si el reward es -10
        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")

# %%
actions

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    env.reset()
    # Crea el estado inicial
    state = env.encode(3, 1, 2, 0)
    env.s = state
    # Inicializa las epochs, penalties y rewards
    epochs, penalties, reward = 0, 0, 0

    done = False
    actions = []
    while not done:
        # Elige la accion que te indique el maximo valor de la q_table
        action = env.action_space.sample()
        actions.append(action)
        # Ejecuta la accion
        state, reward, done, info = env.step(action)

        # Actualiza el valor de penalties si el reward es -10
        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")

# %% [markdown]
# ahora vamos con algo mas dificil

# %% [markdown]
# ## Mario
#
# ![foto9](img/DDQN-1.gif)

# %% [markdown]
# Homer le asignamos una tarea?

# %% [markdown]
# # ...

# %% [markdown]
# ![foto10](img/homero-homer.gif)

# %% [markdown]
# ## FrozenLake

# %%
# crear e inicializar el env
env = gym.make('FrozenLake-v1', is_slippery=False)

# %%
env.reset()

# %%
env.render()

# %%
is_done = False
t = 0
while not is_done:
    action = env.action_space.sample()
    state, reward, is_done, _ = env.step(action)
    env.render()
    t += 1
print('\nlast state =', state)
print('reward = ', reward)
print('time steps =', t)

# %%
state, reward, is_done, _ = env.step(action)
